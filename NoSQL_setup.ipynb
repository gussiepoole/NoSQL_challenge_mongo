# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
import json
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']
  
# Created or Switched to collection
Collection = db['establishments']
 
# Loading or Opening the json file
with open("establishments.json") as file:
    file_data = json.load(file)
     
# Inserting the loaded data in the Collection
# if JSON contains data more than one entry
# insert_many is used else insert_one is used
if isinstance(file_data, list):
    Collection.insert_many(file_data) 
else:
    Collection.insert_one(file_data)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['ClassDB', 'admin', 'autosaurus', 'config', 'epa', 'fruits_db', 'local', 'met', 'travel_db', 'uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db.establishments.find_one()
# Out:
# {'_id': ObjectId('63d10a64eac4f1391ccb71cc'),
#  'FHRSID': 254719,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-03-24T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments_collection = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments_collection.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
establishments_collection.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('63d10a66eac4f1391ccc0d2f'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
rest_cafe_canteen = establishments_collection.find({"BusinessType":"Restaurant/Cafe/Canteen"},{'BusinessTypeID': 1})
for x in rest_cafe_canteen:
    pprint(x)
# Out:
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71cc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71cf')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71d1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71d2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71d3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71d4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71d5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71d6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71db')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71de')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71df')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71e0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71ea')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71ed')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71f1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71fc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb71fe')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7200')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7201')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7204')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7205')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb720a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb720b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb720d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb720e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb720f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7210')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7216')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7217')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb721a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb721e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb721f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7220')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7223')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7225')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7226')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7231')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7232')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7239')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb723a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb723b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb723e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7240')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7241')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7246')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb724e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb724f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7252')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7256')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7257')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7258')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb725a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb725b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7261')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7268')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7269')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb726d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7271')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7277')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7279')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb727b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb727c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb727d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7287')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7288')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb728d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7290')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7295')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7297')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7298')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb729d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72a3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72a5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72ab')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72b8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72ba')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72bb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72bc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72c8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72cb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72cc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72ce')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72d1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72de')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72df')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72e4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72ea')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72ec')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72ee')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72f5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb72fa')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7301')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7306')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7307')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7308')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb730a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb730f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7312')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7314')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7315')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7316')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7319')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb731a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb731b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb731e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb731f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7320')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7321')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7323')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb732a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb732b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7334')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7336')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb733a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb733b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb733e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7345')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7347')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7348')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7349')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb734a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb734d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7351')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7355')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7356')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7357')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7365')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7366')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7368')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb736d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb736e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7375')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7377')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb737a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb737b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7383')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7385')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb738d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7392')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7394')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7396')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7399')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb739c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73a0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73a6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73b1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73bd')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73c7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73e5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73ef')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73f0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73f3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73f6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb73f9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7407')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb741b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7433')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7437')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7443')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7445')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7447')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7449')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7458')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7464')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7465')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb746a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb746e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7471')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7473')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7479')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb747a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb747f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7482')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7483')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7488')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7492')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7493')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7496')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74a3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74a8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74a9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74ae')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74b3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74be')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74c2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74c6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74c7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74d6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74dc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74df')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74e3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74e4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74e7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74e8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74f8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb74ff')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7501')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7507')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb750b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb750c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb750f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7511')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7514')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7516')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7517')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7518')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7519')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7520')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7522')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7523')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7528')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb752a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb752b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb752c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7531')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7533')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb753c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb753d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb753f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7543')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7544')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7547')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7548')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb754c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7550')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7551')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7553')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7555')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7559')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb755a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb755c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7560')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7562')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7566')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7567')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb756c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb756f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7571')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7579')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb757a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb757c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7584')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7585')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7586')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb758c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb758e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7590')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7592')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7598')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7599')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb759b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb759c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb759d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb759e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75a1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75a6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75a8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75a9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75ab')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75b8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75b9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75bc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75bd')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75bf')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75c5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75c6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75c7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75c9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75cb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75cd')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75ce')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75d4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75d7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75d9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75df')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75e9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb75ec')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7601')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7605')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7607')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb760e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb760f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7613')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7617')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391cc
')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bb4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bb6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bb7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bb8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bba')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bbb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bbc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bbd')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bc0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bc2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bc4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bc5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bc7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bca')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bcb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bce')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bcf')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bd1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bd2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bd7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bd8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bd9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bdb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bdd')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7be3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccb7bec')}
# ...
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc09e5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc09ed')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc09f2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc09f4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc09f7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc09fb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a03')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a04')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a05')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a07')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a09')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a0d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a17')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a19')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a1b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a22')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a26')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a27')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a28')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a34')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a39')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a3a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a3c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a3e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a3f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a40')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a42')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a49')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a51')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a55')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a59')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a5e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a67')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a6a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a6c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a6d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a70')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a72')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a73')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a74')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a75')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a76')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a79')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a7a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a85')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a8b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a8f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a90')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a92')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a96')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a99')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a9a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a9b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a9c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a9e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0a9f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aa1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aa2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aab')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aac')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aae')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aaf')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ab2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ab6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ab9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aba')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0abe')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ac0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ac1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ac4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ac9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0acc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ace')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ad0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0adb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ae1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ae5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ae6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ae9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aef')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0af0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0af2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0afb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0afc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0aff')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b02')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b04')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b07')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b08')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b0c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b0f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b13')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b14')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b15')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b19')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b1b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b1c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b1d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b1e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b1f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b20')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b26')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b2a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b2c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b2d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b32')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b3b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b3d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b3e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b43')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b44')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b45')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b46')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b47')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b48')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b4a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b4b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b50')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b51')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b52')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b53')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b56')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b58')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b59')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b5a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b5f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b65')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b67')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b68')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b69')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b6a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b6b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b6d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b72')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b73')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b7d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b7e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b81')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b85')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b8b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b8e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b96')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b97')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0b98')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ba1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bc2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bca')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bce')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bd3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bd4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bd5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bd7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bda')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bdc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bdd')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bde')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bdf')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0be0')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bf1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0bf5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c01')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c03')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c08')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c09')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c15')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c16')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c1a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c1f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c21')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c23')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c24')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c26')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c2e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c3f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c43')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c4d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c4e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c54')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c59')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c5e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c61')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c65')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c6a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c6c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c6e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c72')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c7b')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c7e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c80')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c81')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c82')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c85')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c87')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c88')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c89')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c8c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c8e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c8f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c90')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c95')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c96')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c97')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c99')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c9a')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c9c')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c9d')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c9e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0c9f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ca2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ca7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ca8')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cad')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0caf')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cb1')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cb2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cb7')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cbb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cbe')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cc2')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cce')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cd3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cd5')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cd6')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cdb')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cdc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0ce9')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cf3')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cf4')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0cfc')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d09')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d0e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d13')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d15')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d19')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d1e')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d1f')}
# {'BusinessTypeID': 1, '_id': ObjectId('63d10a64eac4f1391ccc0d2d')}
# {'BusinessTypeID': '', '_id': ObjectId('63d10a66eac4f1391ccc0d2f')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
filter_bus = { "BusinessName":"Penang Flavours" }
 
# Values to be updated.
newvalues = { "$set": { 'BusinessTypeID': 1 } }
 

establishments_collection.update_one(filter_bus, newvalues)

# %%
# Confirm that the new restaurant was updated
establishments_collection.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('63d10a66eac4f1391ccc0d2f'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_data = establishments_collection.count_documents({'LocalAuthorityName': 'Dover'})
dover_data
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments_collection.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
dover_data = establishments_collection.count_documents({'LocalAuthorityName': 'Dover'})
dover_data
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments_collection.find_one()
# Out:
# {'_id': ObjectId('63d10a64eac4f1391ccb74b3'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
db.establishments.update_many({},[
    {'$set': {"geocode.longitude":{'$toDouble':"$geocode.longitude"}}}
])

# %%
# Change the data type from String to Decimal for latitude
db.establishments.update_many({},[
    {'$set': {"geocode.latitude":{'$toDouble':"$geocode.latitude"}}}
])

# %%
# Check that the coordinates are now numbers
establishments_collection.find_one()
# Out:
# {'_id': ObjectId('63d10a64eac4f1391ccb74b3'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}
