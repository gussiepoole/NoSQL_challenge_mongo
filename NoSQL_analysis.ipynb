# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import json
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
# assign the uk_food database to a variable name
db = mongo['uk_food']
  
# Created or Switched to collection
collection = db['establishments']
 
# Loading or Opening the json file
#with open("establishments.json") as file:
#    file_data = json.load(file)
     
# Inserting the loaded data in the Collection
# if JSON contains data more than one entry
# insert_many is used else insert_one is used
#if isinstance(file_data, list):
#    Collection.insert_many(file_data) 
#else:
#    Collection.insert_one(file_data)

# %%
# review the collections in our database
print(mongo.list_database_names())
# Out:
# ['ClassDB', 'admin', 'autosaurus', 'config', 'epa', 'fruits_db', 'local', 'met', 'travel_db', 'uk_food']

# %%
# assign the collection to a variable
establishments_collection = db['establishments']
print(db.list_collection_names())
# Out:
# ['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %%
query = [{'$group': {'_id': "$BusinessName", 'count': { '$sum': 1 }}}]

# %%
results = list(collection.aggregate(query))
results
# Out:
# [{'_id': 'Sunset', 'count': 2},
#  {'_id': 'The Coast Inn', 'count': 2},
#  {'_id': 'Matalan Ltd', 'count': 2},
#  {'_id': 'P Ward & Sons', 'count': 2},
#  {'_id': 'Blakes Leisure Limited', 'count': 2},
#  {'_id': 'S & A Supermarket', 'count': 2},
#  {'_id': 'Arena Food Centre', 'count': 2},
#  {'_id': 'My Bubble Bubble Ltd', 'count': 2},
#  {'_id': 'Lakeside News', 'count': 2},
#  {'_id': 'Noak Bridge Pre School', 'count': 2},
#  {'_id': 'Bucklers', 'count': 2},
#  {'_id': 'Stanway Village Hall', 'count': 2},
#  {'_id': "Luigi's Ristorante", 'count': 2},
#  {'_id': 'Montessori Nursery', 'count': 2},
#  {'_id': 'Cake Studio', 'count': 2},
#  {'_id': 'Simons Salt Beef Sandwiches', 'count': 2},
#  {'_id': 'Oasis Hotel', 'count': 2},
#  {'_id': 'Thrive Outdoor', 'count': 2},
#  {'_id': 'Moving Forward Enterprise', 'count': 2},
#  {'_id': 'Orpington Hospital (ISS Mediclean)', 'count': 2},
#  {'_id': 'Purple Lion Day Nurseries', 'count': 2},
#  {'_id': 'Lost Sheep Coffee', 'count': 2},
#  {'_id': 'The Ongar Grill', 'count': 2},
#  {'_id': 'Phoenix Primary School', 'count': 2},
#  {'_id': 'The Cockpit', 'count': 2},
#  {'_id': 'Lane Tian', 'count': 2},
#  {'_id': 'Beer Barrels 2U', 'count': 2},
#  {'_id': 'Sittingbourne Services Ltd', 'count': 2},
#  {'_id': 'Cobham Manor Coffee Shop', 'count': 2},
#  {'_id': 'Indus Catering', 'count': 2},
#  {'_id': 'Cru', 'count': 2},
#  {'_id': 'Singleton Barn', 'count': 2},
#  {'_id': 'Roccos', 'count': 2},
#  {'_id': 'Lydd Best Kebab', 'count': 2},
#  {'_id': 'Arena Pursuits', 'count': 2},
#  {'_id': 'The Centre Cafe', 'count': 4},
#  {'_id': 'Templeton News', 'count': 2},
#  {'_id': '7 Mamas Ltd', 'count': 2},
#  {'_id': "Cristina's Far from Home LTD", 'count': 2},
#  {'_id': 'Apple Tree Events', 'count': 2},
#  {'_id': 'Corner Shop', 'count': 4},
#  {'_id': 'Josie’s Cakes & Bakes', 'count': 2},
#  {'_id': 'Little Peckers', 'count': 2},
#  {'_id': 'G Leavett', 'count': 2},
#  {'_id': 'Compass Group At Barnehurst Infant & Junior School', 'count': 2},
#  {'_id': 'Eastwood Academy', 'count': 2},
#  {'_id': 'Subco Elders Day Centre', 'count': 2},
#  {'_id': 'Impact Food Group @ Longfield Academy', 'count': 2},
#  {'_id': 'SoPa Thai & Oriental Market', 'count': 2},
#  {'_id': 'Rannah', 'count': 2},
#  {'_id': 'Grove Park Food & Wine', 'count': 2},
#  {'_id': 'Gibsons Cornershop & Deli', 'count': 2},
#  {'_id': 'St Andrews C Of E Primary School', 'count': 4},
#  {'_id': 'Food Shop Bulgaria', 'count': 2},
#  {'_id': 'Worgans Farm Shop', 'count': 2},
#  {'_id': 'Jenny Lind', 'count': 2},
#  {'_id': 'Khan Super Foods Ltd', 'count': 2},
#  {'_id': 'Ice Cream Van X903 PFC', 'count': 2},
#  {'_id': 'Oaks Care Home', 'count': 2},
#  {'_id': 'Roman Road School', 'count': 2},
#  {'_id': 'S K Stores', 'count': 2},
#  {'_id': 'Burger King (Airside)', 'count': 2},
#  {'_id': 'Headstart', 'count': 2},
#  {'_id': 'Mad Cat Brewery', 'count': 2},
#  {'_id': 'Rusthall Lunch Club', 'count': 2},
#  {'_id': 'Helenswood Academy Lower School', 'count': 2},
#  {'_id': 'Mole End Farms Ltd', 'count': 2},
#  {'_id': 'John Lewis', 'count': 4},
#  {'_id': 'Amar Cash And Carry', 'count': 2},
#  {'_id': 'Stratford Picture House', 'count': 2},
#  {'_id': 'Skippers Hill Manor Preparatory School', 'count': 2},
#  {'_id': 'Bakeaways', 'count': 2},
#  {'_id': 'Springfields', 'count': 2},
#  {'_id': "Henry's Bakery", 'count': 2},
#  {'_id': 'Three Eight Chinese Takeaway', 'count': 2},
#  {'_id': 'Oriental Emporium', 'count': 2},
#  {'_id': 'Harrison Catering Services Ltd at Haberdashers Askes Knights',
#   'count': 2},
#  {'_id': 'Laville Limited T/A Britannia Pharmacy', 'count': 2},
#  {'_id': 'Canterbury Leisure', 'count': 2},
#  {'_id': 'Havilah Homes', 'count': 4},
#  {'_id': 'Pho Palace', 'count': 2},
#  {'_id': 'Vivinify.Uk', 'count': 2},
#  {'_id': 'Tudor Lodge', 'count': 2},
#  {'_id': 'Beechcroft Care Home', 'count': 2},
#  {'_id': 'Fung Kitchen', 'count': 2},
#  {'_id': 'Fiskardo Restaurant', 'count': 2},
#  {'_id': 'The Cornish Bakery', 'count': 6},
#  {'_id': 'Pandas Kitchen', 'count': 2},
#  {'_id': 'The Savoury Slice', 'count': 2},
#  {'_id': 'Top Deck Fish Bar', 'count': 2},
#  {'_id': "Anne's Restaurant", 'count': 2},
#  {'_id': 'Birchington Village Bakery', 'count': 2},
#  {'_id': 'East Ham Care Centre', 'count': 2},
#  {'_id': 'Deanland Stores', 'count': 2},
#  {'_id': 'Friars Community Centre', 'count': 2},
#  {'_id': "Kam's Chinese Restaurant", 'count': 2},
#  {'_id': 'Cherrytree, Achieve together', 'count': 2},
#  {'_id': 'The Brothers Fish Bar', 'count': 6},
#  {'_id': 'Chequer Tree Fishery', 'count': 2},
#  {'_id': 'St Mary in the Castle', 'count': 2},
#  {'_id': 'Ö EatÖdrink', 'count': 2},
#  {'_id': 'L&Q Living', 'count': 2},
#  {'_id': 'Manor Farm Oast B&B', 'count': 2},
#  {'_id': 'Cliftonville Outdoor Bowls Club', 'count': 2},
#  {'_id': 'Zeyara', 'count': 4},
#  {'_id': 'Le Bouchon Brasserie And Hotel', 'count': 2},
#  {'_id': 'B\\&M', 'count': 2},
#  {'_id': 'Royal Epping Forest Golf Club', 'count': 2},
#  {'_id': 'Kings Hill Cricket Club', 'count': 2},
#  {'_id': 'Tough Love St Leonards', 'count': 2},
#  {'_id': 'The Croft Day Nursery', 'count': 2},
#  {'_id': 'Market Place Bagel Bar', 'count': 2},
#  {'_id': 'Classic Pot Emporium', 'count': 2},
#  {'_id': 'Nutan Pharmacy', 'count': 2},
#  {'_id': 'Bulls Head Hotel', 'count': 2},
#  {'_id': 'Manor Community Primary School After School Club', 'count': 2},
#  {'_id': 'Chicken Base', 'count': 2},
#  {'_id': 'The Honey Pot', 'count': 4},
#  {'_id': 'Crow And Gate Inn', 'count': 2},
#  {'_id': 'The Firs', 'count': 4},
#  {'_id': "Evina's Coffee Shop", 'count': 2},
#  {'_id': 'Songs Buffet', 'count': 2},
#  {'_id': 'Mr Sandwich Ltd', 'count': 2},
#  {'_id': 'Dellas Chicken', 'count': 2},
#  {'_id': 'The Ivy Leaf', 'count': 2},
#  {'_id': 'Neptunes Table', 'count': 4},
#  {'_id': 'Beijing Chef', 'count': 2},
#  {'_id': 'Savage', 'count': 2},
#  {'_id': 'Cakes From Rachel Xx', 'count': 2},
#  {'_id': 'Evangelical Church', 'count': 4},
#  {'_id': 'Chelmsford Society Of Model Engineers', 'count': 2},
#  {'_id': 'The Pelton Arms', 'count': 2},
#  {'_id': 'Kates Cafe And Restaurant', 'count': 2},
#  {'_id': 'Coddeshall Fish And Chips', 'count': 2},
#  {'_id': 'Ratton Pantry', 'count': 2},
#  {'_id': 'C Major', 'count': 2},
#  {'_id': 'Sushi & Bento House/ Fusion Kimbap', 'count': 2},
#  {'_id': 'Churchill Breakfast And After School Club', 'count': 2},
#  {'_id': 'Marleys', 'count': 2},
#  {'_id': 'B A Fitch Newsagents', 'count': 2},
#  {'_id': 'Holy Family Catholic Primary School', 'count': 2},
#  {'_id': 'Fabulous Tots Nursery', 'count': 2},
#  {'_id': 'Savoy Court Hotel', 'count': 2},
#  {'_id': 'Castledown County Primary School', 'count': 2},
#  {'_id': 'The Chocolate Shop', 'count': 2},
#  {'_id': 'Busy Bees', 'count': 6},
#  {'_id': 'Spyglass And Kettle', 'count': 2},
#  {'_id': 'PCC Trading of Becontree South Food Bank', 'count': 2},
#  {'_id': 'Production Kitchen', 'count': 2},
#  {'_id': 'Colne Valley Golf Club', 'count': 2},
#  {'_id': 'Capel Plough Football Club', 'count': 2},
#  {'_id': 'John Graham Day Centre', 'count': 2},
#  {'_id': 'Winstree Court Day Centre', 'count': 2},
#  {'_id': 'Legends Pool Club', 'count': 2},
#  {'_id': 'Eastbrook Cafe & Restaurant', 'count': 2},
#  {'_id': 'Origin Cafe t/a Chartwells', 'count': 2},
#  {'_id': 'The Springwood Grill', 'count': 2},
#  {'_id': 'Avanti Court Primary School', 'count': 2},
#  {'_id': 'Shakers Bar', 'count': 2},
#  {'_id': 'Snax 24 Ltd', 'count': 2},
#  {'_id': 'Scott Anderson Ltd T/as Stacked', 'count': 2},
#  {'_id': 'Black Horse P H', 'count': 2},
#  {'_id': 'Suffolk Gift Sets', 'count': 2},
#  {'_id': 'Marshview House', 'count': 2},
#  {'_id': 'Beechcare Care Home', 'count': 2},
#  {'_id': 'Surmans', 'count': 2},
#  {'_id': 'KFC (Brook Retail Park)', 'count': 2},
#  {'_id': 'Gurkhas View', 'count': 2},
#  {'_id': 'Elderberries At Belvedere Baptist Church', 'count': 2},
#  {'_id': 'The Hotdog Shack', 'count': 2},
#  {'_id': 'Itsu Stansted', 'count': 2},
#  {'_id': 'Modern News', 'count': 2},
#  {'_id': 'Hawkhurst Pre School', 'count': 2},
#  {'_id': 'Ascension Church Centre', 'count': 2},
#  {'_id': 'ABM@Chipstead Lake Cheshire Home', 'count': 2},
#  {'_id': 'Cheema Brothers', 'count': 2},
#  {'_id': "Deb's Diner", 'count': 2},
#  {'_id': 'Treff Haus Ltd', 'count': 2},
#  {'_id': 'Riverside Pizza', 'count': 2},
#  {'_id': 'Brambletye Hotel And Restaurant', 'count': 2},
#  {'_id': 'The Gelato Connoisseur', 'count': 2},
#  {'_id': 'Premier Education - HAF Project', 'count': 2},
#  {'_id': 'Eastwood Takeaway', 'count': 2},
#  {'_id': 'Flavaz Grill & Kitchen', 'count': 2},
#  {'_id': 'House Of Agnes', 'count': 2},
#  {'_id': 'Banks Restaurant', 'count': 2},
#  {'_id': 'Crayford Weights & Fitness', 'count': 2},
#  {'_id': "EM's Coffee Bar", 'count': 2},
#  {'_id': 'Littleview Day Nursery', 'count': 2},
#  {'_id': 'Rustico Neapolitan Street Food', 'count': 2},
#  {'_id': 'J C Morrison', 'count': 2},
#  {'_id': 'Ninfield C Of E School', 'count': 2},
#  {'_id': 'Edwards & Blake Elior At Trimley St Mary CP School', 'count': 2},
#  {'_id': 'Lister Community School', 'count': 2},
#  {'_id': 'The Outpost Coffee Lounge', 'count': 2},
#  {'_id': 'Old Woodham Road Farm Shop', 'count': 2},
#  {'_id': 'London Agege Bread Bakers Ltd', 'count': 2},
#  {'_id': 'Chicky Chunks', 'count': 2},
#  {'_id': 'St Julians Club', 'count': 2},
#  {'_id': 'Ali Curry House Limited', 'count': 2},
#  {'_id': 'Buzz Cafe - Starbucks', 'count': 2},
#  {'_id': 'Bowden House School', 'count': 2},
#  {'_id': 'Roslin Beach Hotel', 'count': 2},
#  {'_id': 'Joshan of Wye', 'count': 2},
#  {'_id': 'The Belly', 'count': 2},
#  {'_id': 'Co-Op Store', 'count': 2},
#  {'_id': "Col's Icecreams and Events", 'count': 2},
#  {'_id': "St. Cedd's Catholic Club", 'count': 2},
#  {'_id': 'Joydens Wood CP Infants School', 'count': 2},
#  {'_id': 'Atam Academy', 'count': 2},
#  {'_id': 'Friday Club', 'count': 2},
#  {'_id': 'Original Fried Chicken', 'count': 4},
#  {'_id': 'Neptunes Hall', 'count': 2},
#  {'_id': 'Tree Tots Pre-School', 'count': 2},
#  {'_id': 'Tonbridge International Food Centre Ltd', 'count': 2},
#  {'_id': 'Hayat Restaurant', 'count': 2},
#  {'_id': 'Delish By Bish', 'count': 2},
#  {'_id': 'Snack Bar MW Amusements', 'count': 2},
#  {'_id': 'Marks & Spencers Staff Room Vending Only', 'count': 2},
#  {'_id': 'The Jolly Fisherman', 'count': 2},
#  {'_id': 'Travelodge Braintree', 'count': 2},
#  {'_id': 'The Cock Inn', 'count': 24},
#  {'_id': 'Southborough Butchers Ltd', 'count': 2},
#  {'_id': 'The Hall Lakeside', 'count': 2},
#  {'_id': 'Madras Accent', 'count': 2},
#  {'_id': 'The New Deanery Care Village', 'count': 2},
#  {'_id': 'Fairways Newsagent', 'count': 2},
#  {'_id': 'Little Learners', 'count': 2},
#  {'_id': 'St Justus Church Hall', 'count': 2},
#  {'_id': 'Cahoots Novelty Cakes', 'count': 2},
#  {'_id': "Morley's", 'count': 26},
#  {'_id': 'Rosie Lea Tea', 'count': 2},
#  {'_id': 'St Georges School', 'count': 2},
#  {'_id': 'F & S', 'count': 2},
#  {'_id': 'Steeple Bay Holiday Park', 'count': 2},
#  {'_id': 'Kent Elms Tennis Club', 'count': 2},
#  {'_id': 'Greenwoods Hotel', 'count': 2},
#  {'_id': 'Danson Aunties Pre-School At Danson Youth Centre', 'count': 2},
#  {'_id': 'Fairkytes Care Home', 'count': 2},
#  {'_id': "Mrs B's", 'count': 2},
#  {'_id': 'Bluesky Chinese Takeaway', 'count': 2},
#  {'_id': 'Mess Hall', 'count': 2},
#  {'_id': 'Kome Express', 'count': 6},
#  {'_id': 'Northfleet Premier Mart', 'count': 2},
#  {'_id': 'China House', 'count': 2},
#  {'_id': 'Kings Market Store', 'count': 2},
#  {'_id': 'Dining Room By Curryholics', 'count': 2},
#  {'_id': 'Four Season', 'count': 2},
#  {'_id': 'Claremont Senior School', 'count': 2},
#  {'_id': 'Caterlink At Leeds And Broomfield Church Of England Primary',
#   'count': 2},
#  {'_id': 'Don Vincenzo Restaurant', 'count': 2},
#  {'_id': 'Soleil Tanning', 'count': 2},
#  {'_id': "Baldwyn's Park Nursery At Baldwyn's Park Baptist Church",
#   'count': 2},
#  {'_id': 'Wrotham Arms', 'count': 2},
#  {'_id': 'Polisz Szop', 'count': 2},
#  {'_id': 'Windmill Manor Care Home', 'count': 2},
#  {'_id': 'Tonbridge Baptist Church', 'count': 2},
#  {'_id': 'Rush Green Shop', 'count': 2},
#  {'_id': 'Gables Burgers', 'count': 2},
#  {'_id': "Toby's Food & Wine", 'count': 2},
#  {'_id': 'Harolds Park Riding Centre', 'count': 2},
#  {'_id': 'Good Eating Chinese Takeaway', 'count': 2},
#  {'_id': 'Sichuan Bar and Restaurant', 'count': 2},
#  {'_id': "Gulliver's Play Cafe", 'count': 2},
#  {'_id': 'Even Flow', 'count': 4},
#  {'_id': 'St Georges Club', 'count': 2},
#  {'_id': 'Milton Mini Mart', 'count': 2},
#  {'_id': 'Shorne Wood Country Park Visitors Centre', 'count': 2},
#  {'_id': 'The Hare & Hounds', 'count': 2},
#  {'_id': 'Sturry Pre-School', 'count': 2},
#  {'_id': 'St Martins Priory', 'count': 2},
#  {'_id': 'Joseph and Co', 'count': 2},
#  {'_id': 'Kings Farm Grill', 'count': 2},
#  {'_id': 'Hartswood Golf Club', 'count': 2},
#  {'_id': 'Maximum Diner', 'count': 2},
#  {'_id': 'Family, Food & Fun', 'count': 2},
#  {'_id': 'Northern Gateway Sports Club Cuckoo Farm Way', 'count': 2},
#  {'_id': 'St Benedict Bed & Breakfast', 'count': 2},
#  {'_id': "Sainsbury's Local", 'count': 14},
#  {'_id': 'Man Bow House', 'count': 2},
#  {'_id': 'Cafe @ 48', 'count': 2},
#  {'_id': 'Bouttime NN763', 'count': 2},
#  {'_id': 'Gourmet Oriental', 'count': 2},
#  {'_id': 'New Community Church SE London', 'count': 2},
#  {'_id': 'Comptoir Libanais at The Oracle', 'count': 2},
#  {'_id': "Pedro's Fish Bar", 'count': 2},
#  {'_id': 'Fairview Chinese Takeaway', 'count': 2},
#  {'_id': 'Sushi And Bun House', 'count': 2},
#  {'_id': 'The Cooden Beach Hotel', 'count': 2},
#  {'_id': 'Rookhurst Residential Home', 'count': 2},
#  {'_id': 'Nourish Contract Catering Ltd At Ightham Primary School',
#   'count': 2},
#  {'_id': 'The Mayflower', 'count': 2},
#  {'_id': 'Paradise Fast Foods', 'count': 2},
#  {'_id': 'St Winefrides Roman Catholic Primary School', 'count': 2},
#  {'_id': 'Maldon Candy Shop', 'count': 2},
#  {'_id': 'Sasi Cash And Carry', 'count': 2},
#  {'_id': 'The Lamb And Lion Grill', 'count': 2},
#  {'_id': 'Gravesend Burger Kiosk', 'count': 2},
#  {'_id': 'Sophina', 'count': 2},
#  {'_id': 'News Box', 'count': 2},
#  {'_id': 'Felsted Primary School', 'count': 2},
#  {'_id': 'KSN Meat Ltd', 'count': 2},
#  {'_id': 'Green Farm Spa & Retreat', 'count': 2},
#  {'_id': 'Maldon House', 'count': 2},
#  {'_id': 'The Hub Nursery  (food Use)', 'count': 2},
#  {'_id': 'JMS Convenience', 'count': 2},
#  {'_id': 'Niihaw', 'count': 6},
#  {'_id': "Cezar's shop", 'count': 2},
#  {'_id': 'BYO', 'count': 2},
#  {'_id': 'Melting Time', 'count': 2},
#  {'_id': 'The Corn Exchange', 'count': 2},
#  {'_id': 'Mini Marvels Nursery Ltd', 'count': 2},
#  {'_id': 'Junior Kings Kitchen', 'count': 2},
#  {'_id': 'Yogi Pharmacy', 'count': 2},
#  {'_id': 'The Real Ale Way', 'count': 2},
#  {'_id': 'Punnetts Town Community Primary School', 'count': 2},
#  {'_id': 'Mr Softee - Y16 8SR', 'count': 2},
#  {'_id': 'Admiral', 'count': 16},
#  {'_id': 'Kebabery', 'count': 2},
#  {'_id': 'Cocoa Bean Cafe', 'count': 2},
#  {'_id': 'St Andrews C Of E Jmi School', 'count': 2},
#  {'_id': 'Open Road Recovery And Wellbeing', 'count': 2},
#  {'_id': 'Eden Cafe & Catering Limited', 'count': 2},
#  {'_id': "Hibberd's Limited", 'count': 2},
#  {'_id': 'Home Superstore', 'count': 2},
#  {'_id': 'Storeroom', 'count': 2},
#  {'_id': 'Refectory, Tyler House', 'count': 2},
#  {'_id': 'Yaal Restaurant', 'count': 2},
#  {'_id': 'JES General Store', 'count': 2},
#  {'_id': 'Hutton Football Club', 'count': 2},
#  {'_id': 'Leigh And Vic Sandwich Bar', 'count': 2},
#  {'_id': 'Northgate Primary School', 'count': 2},
#  {'_id': 'JavaHub', 'count': 2},
#  {'_id': 'Galata Mezze', 'count': 2},
#  {'_id': 'Jump Giants - Coffee Shop', 'count': 2},
#  {'_id': 'This & That', 'count': 2},
#  {'_id': 'Village Square Cafe', 'count': 2},
#  {'_id': 'Ye Olde Sportsman', 'count': 2},
#  {'_id': 'Slade Green Railway Club', 'count': 2},
#  {'_id': 'New Life Family Church', 'count': 2},
#  {'_id': 'Soka Blackmore Chemist', 'count': 2},
#  {'_id': 'Sugar Rays', 'count': 2},
#  {'_id': 'The Legacy Kingscliff Hotel', 'count': 2},
#  {'_id': 'St Matts Community Food Larder', 'count': 2},
#  {'_id': 'Fez', 'count': 2},
#  {'_id': 'His Place Cafe', 'count': 2},
#  {'_id': 'Beachside Holiday Flats', 'count': 2},
#  {'_id': 'Golden Fish Bar', 'count': 12},
#  {'_id': 'Notorious BRG', 'count': 2},
#  {'_id': 'The Pop Up Seafood Shop', 'count': 2},
#  {'_id': 'Old Kent Roastery', 'count': 2},
#  {'_id': 'Clarkes Fish & Chips', 'count': 2},
#  {'_id': 'Peaberries', 'count': 2},
#  {'_id': 'Chadwell Heath Academy', 'count': 2},
#  {'_id': 'New Jade Garden', 'count': 2},
#  {'_id': "Manor Park Over 50's Social Club", 'count': 2},
#  {'_id': 'Monkey Puzzle Day Nursery', 'count': 8},
#  {'_id': 'Pomodoro & Mozzarella', 'count': 2},
#  {'_id': 'Testerjay', 'count': 2},
#  {'_id': 'Hathats Coffee Company', 'count': 4},
#  {'_id': 'Ideas Hub Chelmsford', 'count': 2},
#  {'_id': 'The Stanway School', 'count': 2},
#  {'_id': 'Basildon Hospital', 'count': 2},
#  {'_id': 'Abbi Wines', 'count': 2},
#  {'_id': 'S M Lucky Store', 'count': 2},
#  {'_id': 'Chadwell Food and Wine', 'count': 2},
#  {'_id': 'Kentmere B&B', 'count': 2},
#  {'_id': 'Fledgelings Nursery', 'count': 2},
#  {'_id': 'Costa Outlet', 'count': 4},
#  {'_id': 'Teatros Bar', 'count': 2},
#  {'_id': 'White Oak Court Sheltered Accommodation', 'count': 2},
#  {'_id': 'Tylers Green Stores', 'count': 2},
#  {'_id': 'The Milk House', 'count': 2},
#  {'_id': 'Gravesham Foodbank', 'count': 6},
#  {'_id': 'Rumours', 'count': 2},
#  {'_id': 'Sittingbourne Golf Centre', 'count': 2},
#  {'_id': 'The Quaives', 'count': 2},
#  {'_id': 'Mel Bowden Catering', 'count': 4},
#  {'_id': 'The Cabin Dairy', 'count': 2},
#  {'_id': 'Girl Guides Association, Guides Camp', 'count': 2},
#  {'_id': 'Weavers Alms Houses', 'count': 2},
#  {'_id': 'Cafe Maz', 'count': 2},
#  {'_id': 'Bawdsey Hall', 'count': 2},
#  {'_id': 'Wethersfield Church Of England Primary School', 'count': 2},
#  {'_id': 'Curbside cafe', 'count': 2},
#  {'_id': 'Bake & Go', 'count': 2},
#  {'_id': 'Independent Catering Management At Parkway Primary School',
#   'count': 2},
#  {'_id': 'Maidstone YMCA', 'count': 2},
#  {'_id': 'Panika', 'count': 2},
#  {'_id': 'Old Chelmsfordians', 'count': 2},
#  {'_id': 'Coffee House', 'count': 6},
#  {'_id': 'Isos Home Foods Grocery', 'count': 2},
#  {'_id': 'The Inn On The Park', 'count': 2},
#  {'_id': 'Harbour Coffee Company', 'count': 2},
#  {'_id': 'Good Food Place', 'count': 2},
#  {'_id': 'MFG Warey Service Station (Esso)', 'count': 2},
#  {'_id': 'St Marguerite Residential Home', 'count': 2},
#  {'_id': 'Bungalow Stores', 'count': 4},
#  {'_id': 'Olivers Nurseries Ltd', 'count': 2},
#  {'_id': 'Smokes & Swaggers', 'count': 2},
#  {'_id': 'Saint Johns Yard', 'count': 2},
#  {'_id': 'Colchester Foodbank', 'count': 6},
#  {'_id': 'Nourish Contract At Bysing Wood County Primary School', 'count': 2},
#  {'_id': 'Oldhams Fish Restaurant', 'count': 2},
#  {'_id': 'Top Tots Boutique', 'count': 2},
#  {'_id': 'Goldfinch Nursery', 'count': 2},
#  {'_id': 'Princes Fish Bar', 'count': 2},
#  {'_id': 'Gun Brewery Ltd', 'count': 2},
#  {'_id': 'Blossoms Preschool & Childrens Centre', 'count': 2},
#  {'_id': 'Cudmore Cafe', 'count': 2},
#  {'_id': 'Ziyafet', 'count': 2},
#  {'_id': 'Halcyon NN114', 'count': 2},
#  {'_id': 'Pressplay Ltd', 'count': 2},
#  {'_id': "Jan's Kitchen", 'count': 2},
#  {'_id': 'Kent Catering Company At Erith Quarry', 'count': 2},
#  {'_id': 'Inn On The Lake Hotel', 'count': 2},
#  {'_id': 'Thurrock Yacht Club', 'count': 2},
#  {'_id': 'Bridge Restaurant & Bar', 'count': 2},
#  {'_id': 'Cafe De Rumpy', 'count': 2},
#  {'_id': 'Ostrich Hotel', 'count': 2},
#  {'_id': 'Cloud9 Espresso Bar and Kitchen', 'count': 2},
#  {'_id': 'Darjeeling Heights', 'count': 2},
#  {'_id': 'Eurest at Ford Dagenham Pitstop', 'count': 2},
#  {'_id': 'Skating Haven Within Newham Leisure Centre', 'count': 2},
#  {'_id': 'Ide Hill Pre-School', 'count': 2},
#  {'_id': 'Mammas', 'count': 2},
#  {'_id': 'Bagel Town', 'count': 2},
#  {'_id': 'Busy Bees Bishops Stortford St Michaels Mead', 'count': 2},
#  {'_id': "Monty's Bar", 'count': 2},
#  {'_id': 'Glorious Africa', 'count': 2},
#  {'_id': 'Age UK Medway', 'count': 2},
#  {'_id': "Amie's Kitchen", 'count': 2},
#  {'_id': 'Greedy Panda', 'count': 2},
#  {'_id': 'Choi Yin', 'count': 2},
#  {'_id': 'Darjeeling Take Away', 'count': 2},
#  {'_id': 'Sams Chicken', 'count': 2},
#  {'_id': 'Sporting Club Thamesmead', 'count': 2},
#  {'_id': 'Strood & Frindsbury Working Mens Clu', 'count': 2},
#  {'_id': 'Truly Chocolicious', 'count': 2},
#  {'_id': "HR's Cafe House", 'count': 2},
#  {'_id': 'Layham Playgroup', 'count': 2},
#  {'_id': 'Sanctuary Group Ltd', 'count': 2},
#  {'_id': 'Jolly Friar Public House', 'count': 2},
#  {'_id': 'Alderwood Primary School', 'count': 2},
#  {'_id': 'Bethel Care Home', 'count': 2},
#  {'_id': 'Oceanic Fish Bar / Pizza Hot', 'count': 2},
#  {'_id': "Cain's Amusements Ltd", 'count': 2},
#  {'_id': 'Emochi', 'count': 2},
#  {'_id': 'Guestling Bradshaw C of E School', 'count': 2},
#  {'_id': 'Warren Wood Social Club', 'count': 2},
#  {'_id': 'Andrews Of Bromley', 'count': 2},
#  {'_id': 'Holy Family Catholic School', 'count': 2},
#  {'_id': 'Pooja Sweets & Savouries', 'count': 2},
#  {'_id': 'Royal Kebabs', 'count': 2},
#  {'_id': 'Northdown CP School Main Kitchen', 'count': 2},
#  {'_id': 'Tollesbury Sailing Club', 'count': 2},
#  {'_id': 'Headway East Sussex', 'count': 2},
#  {'_id': 'Suffolk House Cakerie', 'count': 2},
#  {'_id': 'School 21 - Felix Project', 'count': 2},
#  {'_id': 'Emmanuel Church', 'count': 2},
#  {'_id': '9 FLAGS CAFE BISTRO', 'count': 2},
#  {'_id': 'St Giles Masonic Centre', 'count': 2},
#  {'_id': 'Clare Ellen Guest House', 'count': 2},
#  {'_id': 'Whitebirch Lodge Residential Care Home', 'count': 2},
#  {'_id': 'Blackheath food centre', 'count': 2},
#  {'_id': 'Garden Kitchen Cafe, Braintree Garden Centre Wyevale', 'count': 2},
#  {'_id': 'Le Petit Balcon', 'count': 2},
#  {'_id': 'Lady Room Cakes', 'count': 2},
#  {'_id': 'Costadana', 'count': 2},
#  {'_id': 'Ship Butchery And Delicatessen', 'count': 2},
#  {'_id': 'Tokyo Sizzle', 'count': 2},
#  {'_id': 'Peggottys', 'count': 2},
#  {'_id': 'The Shenfield Wine Company', 'count': 2},
#  {'_id': 'Soul Food', 'count': 2},
#  {'_id': 'The Contract Dining Company At St Katherines CP School', 'count': 2},
#  {'_id': 'Blue Sky Day Nursery', 'count': 2},
#  {'_id': 'Gillingham Indoor Bowls', 'count': 2},
#  {'_id': 'Bromley Beacon Academy Trust - Orpington Campus', 'count': 2},
#  {'_id': 'Busy Bees Pre-School At Methodist Church Hall', 'count': 2},
#  {'_id': 'Bianco 43 Pizza Restaurant', 'count': 2},
#  {'_id': 'Barnston Village Hall', 'count': 2},
#  {'_id': 'Saffron Ice Cream', 'count': 2},
#  {'_id': 'Jump Street Limited', 'count': 2},
#  {'_id': 'French Martini', 'count': 2},
#  {'_id': "Zara's", 'count': 2},
#  {'_id': 'Field Green Oast', 'count': 2},
#  {'_id': 'Mr Burps', 'count': 2},
#  {'_id': 'Willingdon SF Connect', 'count': 2},
#  {'_id': 'Little Oaks Residential Care Home', 'count': 2},
#  {'_id': 'Full of Beans', 'count': 2},
#  {'_id': 'Fairweathers Bistro', 'count': 2},
#  {'_id': 'Roosty’s', 'count': 2},
#  {'_id': 'Home From Home Meals', 'count': 2},
#  {'_id': 'Jubilee Takeaway', 'count': 2},
#  {'_id': 'Dale Lodge Residential Home', 'count': 2},
#  {'_id': 'Live Lounge', 'count': 2},
#  {'_id': 'Taylors Fish And Chips', 'count': 2},
#  {'_id': 'The Entertainer', 'count': 2},
#  {'_id': 'Cottage Bakery', 'count': 4},
#  {'_id': '3 Kumar Supermarket', 'count': 2},
#  {'_id': 'Eltham Cafe', 'count': 2},
#  {'_id': 'Sunflower Day Nursery & Kids Club', 'count': 2},
#  {'_id': 'Park Inn', 'count': 4},
#  {'_id': 'Mr Mel', 'count': 2},
#  {'_id': 'The  Half Moon', 'count': 2},
#  {'_id': "Appleton's", 'count': 2},
#  {'_id': 'Deveci Fish Bar', 'count': 2},
#  {'_id': 'Churchill Contract Catering T/a Radish', 'count': 2},
#  {'_id': 'Oval Cafe', 'count': 2},
#  {'_id': 'Happy Cat Coffee', 'count': 2},
#  {'_id': 'Zest Cafe & Bar', 'count': 2},
#  {'_id': 'The Jenny Wren', 'count': 2},
#  {'_id': "IRMA'S CB LIMITED", 'count': 2},
#  {'_id': 'XIX Littlestone Warren Golf Club', 'count': 2},
#  {'_id': 'Five Stacks Residential Home', 'count': 2},
#  {'_id': 'The PavilionCommunity Sports & Social Club', 'count': 2},
#  {'_id': 'YMCA ESSEX- Out Of School Club @ Baddow Hall Junior School',
#   'count': 2},
#  {'_id': 'Carlisle Lodge Nursing Home', 'count': 2},
#  {'_id': 'Glengariff', 'count': 2},
#  {'_id': 'Westerham Height Nurseries', 'count': 2},
#  {'_id': 'Danny & Eileens', 'count': 2},
#  {'_id': 'Toomai Square', 'count': 2},
#  {'_id': 'Cafe Viva', 'count': 2},
#  {'_id': 'Noahs Ark Nursery', 'count': 2},
#  {'_id': "Julia & Sylvia's Wraparound Care", 'count': 2},
#  {'_id': 'Farnham Green Primary School', 'count': 2},
#  {'_id': 'Normanhurst Court Caravan Club', 'count': 2},
#  {'_id': 'Lodge Newsagents', 'count': 2},
#  {'_id': "B & D's Cafe & Grill", 'count': 2},
#  {'_id': 'Appertize Catering (2)', 'count': 2},
#  {'_id': 'WF Catering at Leytonstone School', 'count': 2},
#  {'_id': 'Folkestone Rainbow Centre Pre-school', 'count': 2},
#  {'_id': 'Ayletts Residential Home', 'count': 2},
#  {'_id': 'Chatham Express', 'count': 2},
#  {'_id': 'The Source Coffee Shop', 'count': 2},
#  {'_id': 'Pulled And Slaw', 'count': 2},
#  {'_id': 'Holy Innocents Catholic Church', 'count': 2},
#  {'_id': 'Out Fry', 'count': 2},
#  {'_id': "Jim's Fish Bar", 'count': 2},
#  {'_id': 'Moz 50 Flavours', 'count': 2},
#  {'_id': 'Oaks Cafe Deli', 'count': 2},
#  {'_id': 'Rush Green Preschool', 'count': 2},
#  {'_id': 'Milestone Marble Cafe', 'count': 2},
#  {'_id': 'Wave Leisure', 'count': 4},
#  {'_id': 'The Plough Bar & Grill Ltd', 'count': 2},
#  {'_id': 'Hutton Cricket Club( Windmill Ground)', 'count': 2},
#  {'_id': 'Dennis Of Bexley', 'count': 2},
#  {'_id': 'Little Elephant', 'count': 2},
#  {'_id': 'Banquet', 'count': 2},
#  {'_id': 'The Woodland Bistro', 'count': 2},
#  {'_id': 'Wickford Junior School', 'count': 2},
#  {'_id': 'Faulkbourne Village Hall', 'count': 2},
#  {'_id': 'Thyme Restaurant & Bar At Premier Inn', 'count': 2},
#  {'_id': 'Daly Convenience Store', 'count': 2},
#  {'_id': 'Hare & Hounds', 'count': 2},
#  {'_id': 'Homeleigh Residential Care Home', 'count': 2},
#  {'_id': 'Caterlink Ltd At St Marks School', 'count': 2},
#  {'_id': 'Roberta House', 'count': 2},
#  {'_id': 'Leigh Bistro', 'count': 2},
#  {'_id': 'The Bearded Butcher', 'count': 2},
#  {'_id': 'Costa Coffee (East)', 'count': 2},
#  {'_id': 'Macknade', 'count': 2},
#  {'_id': 'Cuxton Social Club', 'count': 2},
#  {'_id': 'Frandoz', 'count': 2},
#  {'_id': 'Woodfield Food & Wine', 'count': 2},
#  {'_id': 'Barnardos Childrens Centre', 'count': 2},
#  {'_id': 'Saffron And Sage', 'count': 2},
#  {'_id': 'Mayvin Pastries', 'count': 2},
#  {'_id': 'Royal Eastbourne Golf Club', 'count': 2},
#  {'_id': 'KO (Kebabish Original)', 'count': 2},
#  {'_id': 'Iffin Farmhouse', 'count': 2},
#  {'_id': 'Tesco Garage', 'count': 6},
#  {'_id': 'Olins Pharmacy', 'count': 2},
#  {'_id': 'Horse And Groom P H', 'count': 2},
#  {'_id': 'Oui Chef Catering Group Ltd', 'count': 2},
#  {'_id': 'Favorita House', 'count': 2},
#  {'_id': 'Dockside Day Nursery And Pre School', 'count': 2},
#  {'_id': 'A S Stores', 'count': 2},
#  {'_id': 'Menkind', 'count': 2},
#  {'_id': 'Londis @ MFG Service Station', 'count': 2},
#  {'_id': 'Dawn To Dusk Day Nursery Swanley Ltd', 'count': 2},
#  {'_id': 'Connaught Bingo', 'count': 2},
#  {'_id': 'The Station Hotel', 'count': 2},
#  {'_id': 'Lighthouse Childminding', 'count': 2},
#  {'_id': 'Hantverk & Found', 'count': 2},
#  {'_id': "Shop'n Drive INKL", 'count': 2},
#  {'_id': 'Maltreath', 'count': 2},
#  {'_id': 'Summerdale Court Care Centre', 'count': 2},
#  {'_id': 'Plant Base LOS', 'count': 2},
#  {'_id': 'Mixta', 'count': 2},
#  {'_id': 'Itsu', 'count': 2},
#  {'_id': 'Papa John', 'count': 2},
#  {'_id': 'Hawkinge County Primary School', 'count': 2},
#  {'_id': 'Eggs Eleven', 'count': 2},
#  {'_id': 'Muffin Break', 'count': 18},
#  {'_id': 'Castle Inn', 'count': 8},
#  {'_id': 'Smacks Hamburgers - Orpington', 'count': 2},
#  {'_id': 'Deli 141', 'count': 2},
#  {'_id': 'Weald Club For Disabled People', 'count': 2},
#  {'_id': 'The Gardeners Retreat Restaurant', 'count': 2},
#  {'_id': 'Bella John Fish And Chips', 'count': 2},
#  {'_id': 'Tasty African Foods', 'count': 2},
#  {'_id': "Bridget's Bistro", 'count': 2},
#  {'_id': 'Letsco Supermarket', 'count': 2},
#  {'_id': 'Delmergate Pharmacy', 'count': 2},
#  {'_id': 'Seamead Ltd', 'count': 2},
#  {'_id': 'Olive Dining @ The Skinners Kent Academy', 'count': 2},
#  {'_id': 'Cornerstone Coffee', 'count': 2},
#  {'_id': 'The Kinki', 'count': 2},
#  {'_id': 'The Pier Hotel', 'count': 2},
#  {'_id': 'Monkey Puzzle Eltham', 'count': 2},
#  {'_id': 'Smiley Ark Kids At Mayplace Primary School', 'count': 2},
#  {'_id': 'The Co-Op Food', 'count': 2},
#  {'_id': 'Pypers Hatch Food & Wine', 'count': 2},
#  {'_id': 'Twinstead Cricket Club', 'count': 2},
#  {'_id': 'Best One Convenience store', 'count': 2},
#  {'_id': 'William Bendlowe Charity', 'count': 2},
#  {'_id': 'Blue Orchid', 'count': 2},
#  {'_id': 'Barking Seafood Centre', 'count': 2},
#  {'_id': 'St Mary Magdalene Primary School', 'count': 2},
#  {'_id': 'Safari International', 'count': 2},
#  {'_id': 'Mr Cavendish', 'count': 2},
#  {'_id': '786 Halal Meat and Fish', 'count': 2},
#  {'_id': 'Samrat Tandoori Restaurant', 'count': 2},
#  {'_id': 'Ghyll Farm', 'count': 2},
#  {'_id': 'Claydons', 'count': 2},
#  {'_id': 'Bakers + Baristas', 'count': 2},
#  {'_id': 'Marmaris Kebab House', 'count': 2},
#  {'_id': 'HomeFix Store', 'count': 2},
#  {'_id': 'Route 66 America Fast Food', 'count': 2},
#  {'_id': 'Stiles Garage Shop', 'count': 2},
#  {'_id': 'St Barnabas Pre School Nursery', 'count': 2},
#  {'_id': 'Pages Homes Ltd', 'count': 2},
#  {'_id': 'Lebanese Grill', 'count': 2},
#  {'_id': 'Village Grill', 'count': 2},
#  {'_id': 'Princes Room Restaurant And Training Room', 'count': 2},
#  {'_id': 'ATES Supermarket', 'count': 2},
#  {'_id': 'Masterpiece', 'count': 2},
#  {'_id': 'Wigmore Fish Bar', 'count': 2},
#  {'_id': 'Woolpack Inn', 'count': 4},
#  {'_id': 'Leigh Road Baptist Church Hall', 'count': 2},
#  {'_id': 'Alpha Breakfast / Afterschool Club @ Alderwood Primary School',
#   'count': 2},
#  {'_id': 'Chick Chicken', 'count': 4},
#  {'_id': "Lynne's Organic Farm", 'count': 2},
#  {'_id': 'Arcade Gift Shop', 'count': 2},
#  {'_id': "J D's Pie 'n' Mash", 'count': 2},
#  {'_id': 'Sukhothai', 'count': 2},
#  {'_id': 'Playdays Preschool 6', 'count': 2},
#  {'_id': 'Chutney Chaat', 'count': 2},
#  {'_id': 'East Of England Co Op Service Station', 'count': 2},
#  {'_id': 'Great Chart and Singleton Pre-School', 'count': 2},
#  {'_id': 'The Pantry, Age Concern', 'count': 2},
#  {'_id': 'Caffe Italiano Ltd', 'count': 2},
#  {'_id': 'The Stephen Perse Foundation Dame Bradbury Junior School',
#   'count': 2},
#  {'_id': 'Neptune Snooker Club', 'count': 2},
#  {'_id': 'The Family Choice (UK) Limited', 'count': 2},
#  {'_id': 'Sels Kebab', 'count': 2},
#  {'_id': 'Copdock & OI Cricket Club', 'count': 2},
#  {'_id': 'St Johns Arts And Recreation Centre', 'count': 2},
#  {'_id': 'Archery House Hospital And Staff Restaurant', 'count': 2},
#  {'_id': 'ISS Caterhouse At Pear Tree Mead Academy', 'count': 2},
#  {'_id': 'Sanctuary Care, Meadows View Care Home', 'count': 2},
#  {'_id': 'Pizza Express', 'count': 36},
#  {'_id': 'Toms Newsagents Ltd / West Ham Mini Market', 'count': 2},
#  {'_id': 'Barnston Football Club', 'count': 2},
#  {'_id': 'The Starving Donkey', 'count': 2},
#  {'_id': 'Perryfields County Junior', 'count': 2},
#  {'_id': 'Brent School Old Boys Social Club', 'count': 2},
#  {'_id': 'WO and Sgts Mess', 'count': 2},
#  {'_id': 'The Mount Camphill Ltd', 'count': 2},
#  {'_id': 'Saplings', 'count': 2},
#  {'_id': 'Matestone Coffee And Tea House', 'count': 2},
#  {'_id': 'Pound Plus World', 'count': 2},
#  {'_id': 'Bromley Off Licence Gadgets & Vapes', 'count': 2},
#  {'_id': 'Brishing Barn Nursery', 'count': 2},
#  {'_id': 'Players Lounge', 'count': 2},
#  {'_id': 'Leytonstone Tavern', 'count': 2},
#  {'_id': 'White Rock Convenience Food Market', 'count': 2},
#  {'_id': 'The Dog and Pickle', 'count': 2},
#  {'_id': 'Jugaad Kitchen', 'count': 2},
#  {'_id': 'Hawkinge Convenience Store', 'count': 2},
#  {'_id': 'The Appleyard Sports Ground', 'count': 2},
#  {'_id': 'All Saints Roman Catholic Lower School', 'count': 2},
#  {'_id': 'Roper Dixons Farm (Jacks Juice)', 'count': 2},
#  {'_id': 'Camping International', 'count': 2},
#  {'_id': 'Otford Church Hall, The Methodist Church', 'count': 2},
#  {'_id': 'Northgate Convenience Ltd', 'count': 2},
#  {'_id': 'Arps Stores - Stores Day 1', 'count': 2},
#  {'_id': 'Aqua Bay Guest House', 'count': 2},
#  {'_id': 'Mr Mulligans Coffee Shop', 'count': 2},
#  {'_id': 'Rainham Food & Wine', 'count': 2},
#  {'_id': 'Adnams Cellar And Kitchen', 'count': 2},
#  {'_id': 'Triangle Day Nursery', 'count': 2},
#  {'_id': 'Bonnygate Primary School', 'count': 2},
#  {'_id': 'Rapid Relief Team', 'count': 2},
#  {'_id': 'C.M Fruit & Vegetable', 'count': 2},
#  {'_id': 'Colebrook Hostel', 'count': 2},
#  {'_id': 'Vision Redbridge Culture & Leisure', 'count': 2},
#  {'_id': 'Old Swan Tea Shop', 'count': 2},
#  {'_id': 'The Laughing Barrel', 'count': 2},
#  {'_id': 'Goodmans @ The Courtyard', 'count': 2},
#  {'_id': 'Saltwater/Krispy Chicks', 'count': 2},
#  {'_id': 'Silverhill Service Station', 'count': 2},
#  {'_id': 'The Consumer Engagement Company (Nespresso)', 'count': 2},
#  {'_id': 'Holy Cross Catholic Primary Academy', 'count': 2},
#  {'_id': 'SO11FTY', 'count': 2},
#  {'_id': 'The St Aubyn Centre', 'count': 2},
#  {'_id': "Chris' Famous Fish", 'count': 2},
#  {'_id': "King's Rochester, School House", 'count': 2},
#  {'_id': 'Biryani Flavas', 'count': 2},
#  {'_id': 'Greenwich Convenience Store', 'count': 2},
#  {'_id': 'Ashcroft House', 'count': 4},
#  {'_id': 'Italian Coffee', 'count': 2},
#  {'_id': 'Windmill Drive Cafe', 'count': 2},
#  {'_id': 'Teston & Wateringbury Pre-School', 'count': 2},
#  {'_id': 'AZAAD Newsagent', 'count': 2},
#  {'_id': 'The Thatchers Arms', 'count': 2},
#  {'_id': 'Pizza Express / Mac & Wings', 'count': 4},
#  {'_id': 'Regent House', 'count': 2},
#  {'_id': 'Angus House Catering Co', 'count': 2},
#  {'_id': "Thai 'n' Chinese", 'count': 2},
#  {'_id': 'James Hunt Fisheries', 'count': 2},
#  {'_id': 'KFC Southend', 'count': 2},
#  {'_id': 'Best Inn Hotel', 'count': 2},
#  {'_id': 'Cineworld Cinemas', 'count': 6},
#  {'_id': 'Balance Bar', 'count': 2},
#  {'_id': 'Sub Zero', 'count': 2},
#  {'_id': 'The Axe', 'count': 2},
#  {'_id': 'Dessert Island', 'count': 2},
#  {'_id': 'All Saints C of E (VA) Primary School', 'count': 2},
#  {'_id': 'Moon on the Square', 'count': 2},
#  {'_id': 'Jo Richardson Secondary School', 'count': 4},
#  {'_id': 'SILVER RIVER', 'count': 2},
#  {'_id': 'St Giles College', 'count': 2},
#  {'_id': 'GreenCafe', 'count': 2},
#  {'_id': 'Clavering Village Hall', 'count': 2},
#  {'_id': 'The Moat', 'count': 2},
#  {'_id': "Fish 'N' Chix", 'count': 2},
#  {'_id': 'Scolarest At Herne Infant School', 'count': 2},
#  {'_id': 'Park Resorts Boathouse Restaurant', 'count': 2},
#  {'_id': 'Hot Dog Bar At Adventure Island', 'count': 2},
#  {'_id': 'Boots The Chemist Plc', 'count': 2},
#  {'_id': 'The Furze Wren', 'count': 2},
#  {'_id': 'Silas Food Ltd', 'count': 2},
#  {'_id': 'Patanjali Ayurveda Health Centre', 'count': 2},
#  {'_id': 'Dragons Den Ltd TA Romford Delight', 'count': 2},
#  {'_id': 'Lime Tree House Residential Home', 'count': 2},
#  {'_id': 'The Cottage Restaurant', 'count': 2},
#  {'_id': "Anna's Cafe", 'count': 2},
#  {'_id': 'Chateau Kitunga', 'count': 2},
#  {'_id': 'Raglan Primary School', 'count': 2},
#  {'_id': 'The Barn Nursery School', 'count': 2},
#  {'_id': 'SEAFOOD MANIA', 'count': 2},
#  {'_id': 'Friends Cafe Strood', 'count': 2},
#  {'_id': 'West Street Vineyard', 'count': 2},
#  {'_id': 'Thorndon Park Golf Club', 'count': 2},
#  {'_id': 'Fobbing Village Pre School', 'count': 2},
#  {'_id': 'Subhan Super Store', 'count': 2},
#  {'_id': 'The London Marathon Playing Field', 'count': 2},
#  {'_id': 'Dial A Kebab', 'count': 2},
#  {'_id': 'St Mary Food And Wine - Premier Express', 'count': 2},
#  {'_id': 'Fagins', 'count': 2},
#  {'_id': 'Sandhurst Primary School Breakfast Club', 'count': 2},
#  {'_id': 'Reynolds Retreat', 'count': 2},
#  {'_id': 'Castle Stores', 'count': 2},
#  {'_id': 'Elham Valley Line Trust', 'count': 2},
#  {'_id': 'Brownhill Care Ltd', 'count': 2},
#  {'_id': 'Nisa Local Freshway', 'count': 2},
#  {'_id': 'Green Parks House - Iss Mediclean', 'count': 2},
#  {'_id': 'Barbeque Express', 'count': 2},
#  {'_id': 'The Burger Shack', 'count': 2},
#  {'_id': 'Honeycomb News', 'count': 2},
#  {'_id': 'Chelmsford Hockey Club', 'count': 2},
#  {'_id': 'Hastings Court', 'count': 2},
#  {'_id': 'Nats Snax', 'count': 2},
#  {'_id': 'Food Labs', 'count': 2},
#  {'_id': 'Woodham Mortimer Golf Range', 'count': 2},
#  {'_id': 'UK LATIN COMMUNITY CIC', 'count': 2},
#  {'_id': 'Royal Ashdown Forest Golf Club', 'count': 2},
#  {'_id': 'Preto Chelmsford Ltd', 'count': 2},
#  {'_id': 'Lake View Palace', 'count': 2},
#  {'_id': 'FCB Artisan Espresso Bar', 'count': 2},
#  {'_id': 'Johnsons Fruiterers LTD', 'count': 2},
#  {'_id': 'Billy Hundreds', 'count': 2},
#  {'_id': 'Russell Lodge', 'count': 2},
#  {'_id': 'The Watering Can', 'count': 2},
#  {'_id': 'Luton Junior School', 'count': 2},
#  {'_id': 'The Four Elms Inn', 'count': 2},
#  {'_id': 'Weddings & Events & Felicitys Cafe', 'count': 2},
#  {'_id': 'Sol Y Sombra', 'count': 2},
#  {'_id': 'The Fig Wine Bar Ltd', 'count': 2},
#  {'_id': 'Richard De Clare Primary School', 'count': 2},
#  {'_id': 'Magazin Romanesc Anais', 'count': 2},
#  {'_id': 'Sathyam', 'count': 2},
#  {'_id': 'Rankins Catering', 'count': 2},
#  {'_id': 'Clacton Indoor Bowls Club', 'count': 2},
#  {'_id': 'Cafe 5', 'count': 2},
#  {'_id': 'Owl & Pussycat', 'count': 4},
#  {'_id': 'Nationwide Community Care', 'count': 2},
#  {'_id': 'Seal Community Lunch', 'count': 2},
#  {'_id': 'Sidcup Food & Wine', 'count': 2},
#  {'_id': 'St. John Fisher Lower', 'count': 2},
#  {'_id': 'The White Rose', 'count': 2},
#  {'_id': 'The Kentish Hare', 'count': 2},
#  {'_id': 'St Thomas More Catholic Primary School', 'count': 2},
#  {'_id': 'The Britannia', 'count': 6},
#  {'_id': 'Toclair Afro Foods', 'count': 2},
#  {'_id': 'C Percy Limited', 'count': 2},
#  {'_id': "Rafferty's", 'count': 2},
#  {'_id': 'Sherington Primary School', 'count': 2},
#  {'_id': 'Schoolgate Nursery', 'count': 2},
#  {'_id': 'Amala', 'count': 2},
#  {'_id': "St.Leonard's", 'count': 2},
#  {'_id': 'Carmel Caterpillars', 'count': 2},
#  {'_id': 'Trotters', 'count': 2},
#  {'_id': 'Gourmet Express', 'count': 2},
#  {'_id': 'Romford Conservative Club', 'count': 2},
#  {'_id': 'Pitta Maria', 'count': 2},
#  {'_id': 'Canterbury Cathedral Lodge', 'count': 2},
#  {'_id': 'Rosewood Afterschool Club', 'count': 2},
#  {'_id': 'Mr Mulligans', 'count': 2},
#  {'_id': 'Bar-B-Q House', 'count': 2},
#  {'_id': 'Bar-b-q-house', 'count': 2},
#  {'_id': 'OUT OF DATE WHOLESALE', 'count': 2},
#  {'_id': "It's All Gravy", 'count': 2},
#  {'_id': 'St Augustine Of Canterbury Church', 'count': 2},
#  {'_id': "Donna's Ale House", 'count': 2},
#  {'_id': 'Traditional Fish And Chips', 'count': 2},
#  {'_id': 'Victory Park Academy & Sutton House Academy', 'count': 2},
#  {'_id': 'Madison Heights', 'count': 2},
#  {'_id': 'Dartford Valley Rugby Club', 'count': 2},
#  {'_id': 'Petts Wood Bowling Club', 'count': 2},
#  {'_id': 'Peri Peri Chicken', 'count': 2},
#  {'_id': 'A La Carte Spice', 'count': 2},
#  {'_id': 'CTN Frindsbury Newsagents', 'count': 2},
#  {'_id': 'Mountain Ash Residential Home', 'count': 2},
#  {'_id': 'The Avenues Social Club Limited', 'count': 2},
#  {'_id': 'Luxford Centre Lunch Club', 'count': 2},
#  {'_id': 'The Good Food Box', 'count': 2},
#  {'_id': 'Byers Bakery Ltd', 'count': 2},
#  {'_id': 'Kings Hill Golf Club', 'count': 2},
#  {'_id': 'Firecracker Canteen', 'count': 2},
#  {'_id': 'Cobbs Hill Farmshop', 'count': 2},
#  {'_id': 'Dinner Box', 'count': 2},
#  {'_id': 'Thorpe Hall School', 'count': 2},
#  {'_id': 'Megan Austin BSc', 'count': 2},
#  {'_id': 'K15 EPS', 'count': 2},
#  {'_id': 'Elysium Refll', 'count': 2},
#  {'_id': '7 Day Chemist', 'count': 2},
#  {'_id': 'Phoenix Smokery Ltd', 'count': 2},
#  {'_id': 'Sea Fresh Fish Bar', 'count': 2},
#  {'_id': 'Harlow Mill Restaurant & Premier Inn', 'count': 2},
#  {'_id': 'Vapes Cakes & Shakes', 'count': 2},
#  {'_id': 'FAVOURITE AFRICAN RESTAURANT', 'count': 2},
#  {'_id': 'Shabash', 'count': 2},
#  {'_id': 'The Clipper', 'count': 2},
#  {'_id': 'ECL Care &  Wellbeing Hub', 'count': 2},
#  {'_id': 'Maemes', 'count': 2},
#  {'_id': 'Gourmet Sweets & Bakers', 'count': 2},
#  {'_id': 'Sonali Indian Take Away', 'count': 2},
#  {'_id': 'Epping Forest Hotel', 'count': 2},
#  {'_id': 'Cygnets Pre-School', 'count': 2},
#  {'_id': 'Bronte School', 'count': 2},
#  {'_id': 'Westgate United Services Club', 'count': 2},
#  {'_id': 'Zaabthai', 'count': 2},
#  {'_id': 'Beacon Hill Academy', 'count': 2},
#  {'_id': 'Rhythm N Thyme', 'count': 2},
#  {'_id': "Naz's Rasoi", 'count': 2},
#  {'_id': 'Plaistow Park Community Centre', 'count': 2},
#  {'_id': 'Food Stop', 'count': 4},
#  {'_id': 'Parlour Cafe', 'count': 2},
#  {'_id': 'Bombers Cafe', 'count': 2},
#  {'_id': "Anne's Pantry Ltd", 'count': 2},
#  {'_id': "Salami's Kebab House", 'count': 2},
#  {'_id': 'Heath Farm Family Services Ltd', 'count': 2},
#  {'_id': 'Island Residential Home', 'count': 2},
#  {'_id': 'Whittakers', 'count': 2},
#  {'_id': 'Coopersale & Theydon GarnonPrimary S', 'count': 2},
#  {'_id': 'Ocklynge Manor', 'count': 2},
#  {'_id': 'Ocean Swell Residential Home', 'count': 2},
#  {'_id': 'Staplehurst Cottage', 'count': 2},
#  {'_id': 'Southend Lawn Tennis Club', 'count': 2},
#  {'_id': 'Boreham Post Office & News', 'count': 2},
#  {'_id': 'Glynde Post Office And Stores', 'count': 2},
#  {'_id': 'East Peckham Newsagent', 'count': 2},
#  {'_id': 'Tinukace Foods', 'count': 2},
#  {'_id': 'Dartford Invicta Bowls Club', 'count': 2},
#  {'_id': 'Grange House', 'count': 2},
#  {'_id': 'Waleed Halal Meat', 'count': 2},
#  {'_id': 'Madina', 'count': 2},
#  {'_id': 'Jay Jay Oriental Takeaway', 'count': 2},
#  {'_id': 'The Churchyard Tea Room', 'count': 2},
#  {'_id': 'The Playhouse', 'count': 4},
#  {'_id': 'Bonkers4Baking', 'count': 2},
#  {'_id': 'Solanki Chemists', 'count': 2},
#  {'_id': 'Visitors Centre Tea Bar', 'count': 2},
#  {'_id': 'Cross In Hand Tennis Club', 'count': 2},
#  {'_id': 'Green Village', 'count': 2},
#  {'_id': 'Leys Nursery', 'count': 2},
#  {'_id': 'Marsh Mellow', 'count': 2},
#  {'_id': 'Daows Thai Kitchen', 'count': 2},
#  {'_id': 'La Baguette Shop', 'count': 2},
#  {'_id': 'Russell Up Events Ltd', 'count': 2},
#  {'_id': 'Balloonista Ltd', 'count': 2},
#  {'_id': 'The Oak Bakery', 'count': 2},
#  {'_id': 'D G W Meats', 'count': 2},
#  {'_id': "Cherry Tree Kids Club At The Children's Centre", 'count': 2},
#  {'_id': 'Rustic Shop Costan Ltd', 'count': 2},
#  {'_id': "Topp's Seafood", 'count': 2},
#  {'_id': 'M&S Simply Food', 'count': 4},
#  {'_id': "Vinny's Restaurant", 'count': 2},
#  {'_id': 'Tony Lorenzo Patisserie & Deli', 'count': 2},
#  {'_id': 'Taylor Meats Ltd', 'count': 4},
#  {'_id': 'Ye Olde Leather Bottle', 'count': 2},
#  {'_id': 'Henry Green Primary School', 'count': 2},
#  {'_id': 'Riverview Foods', 'count': 2},
#  {'_id': 'The Tea House B&B', 'count': 2},
#  {'_id': 'Milk and Hustle', 'count': 2},
#  {'_id': 'Charles Darwin School - Independent Catering', 'count': 2},
#  {'_id': "Churchill's Fish & Chips", 'count': 4},
#  {'_id': 'Singleton Pizza & Kebab', 'count': 2},
#  {'_id': 'Down House Tearoom', 'count': 2},
#  {'_id': 'Paradise Groceries Ltd', 'count': 2},
#  {'_id': 'Sidley Village Butchers', 'count': 2},
#  {'_id': 'New China Gold', 'count': 2},
#  {'_id': 'Flatford Mill Centre', 'count': 2},
#  {'_id': 'E-Cool UK', 'count': 2},
#  {'_id': 'Windrush Primary School (Bentham Road)', 'count': 2},
#  {'_id': 'Plough & Chequers PH', 'count': 2},
#  {'_id': 'Pilot Inn', 'count': 2},
#  {'_id': 'Playaway Nursery (SRCC)', 'count': 2},
#  {'_id': 'Beehive Playgroup', 'count': 2},
#  {'_id': 'Holiday Inn (Traders Bar And Grill)', 'count': 2},
#  {'_id': "Jenny's Cafe", 'count': 2},
#  {'_id': 'Bosuns', 'count': 2},
#  {'_id': 'Chikk Ltd', 'count': 2},
#  {'_id': 'Oak House Childrens Home Ltd', 'count': 2},
#  {'_id': 'St Augustine Academy', 'count': 2},
#  {'_id': 'Around The Clock', 'count': 2},
#  {'_id': 'Tilbury Cash And Carry', 'count': 2},
#  {'_id': 'Excel London Hospitality', 'count': 2},
#  {'_id': 'Broomfield Stores', 'count': 2},
#  {'_id': 'Adyar Ananda Bhavan', 'count': 2},
#  {'_id': 'The Stone Inn Public House Ltd', 'count': 2},
#  {'_id': 'Mix Food Unite', 'count': 2},
#  {'_id': 'Taras Beach Hut', 'count': 2},
#  {'_id': 'Cafe Inn', 'count': 4},
#  {'_id': 'Donut Time Limited', 'count': 2},
#  {'_id': 'The Refill Room', 'count': 2},
#  {'_id': 'Phoenix Day Nursery', 'count': 2},
#  {'_id': 'No Harm Products', 'count': 2},
#  {'_id': 'Ospringe Fish Bar', 'count': 2},
#  {'_id': "Bill's Tunbridge Wells", 'count': 2},
#  {'_id': 'Banana Moon Colchester', 'count': 2},
#  {'_id': 'Blueberry Lounge', 'count': 2},
#  {'_id': 'Ardealu', 'count': 2},
#  {'_id': "Jesse's Cafe", 'count': 2},
#  {'_id': 'Bell & Crown Public House', 'count': 2},
#  {'_id': 'Valley View Residential Nursing Home', 'count': 2},
#  {'_id': 'Westwood Montessori Nursery', 'count': 2},
#  {'_id': 'Gourmet Bakers & Sweets', 'count': 2},
#  {'_id': "Morgan's Bistro Ltd", 'count': 2},
#  {'_id': 'Mulberry House', 'count': 2},
#  {'_id': 'Quayside Kitchen', 'count': 2},
#  {'_id': 'Preto', 'count': 2},
#  {'_id': 'Danehurst House', 'count': 2},
#  {'_id': 'Brinkley Grove Primary School', 'count': 2},
#  {'_id': 'Leysdown Seafood Bar', 'count': 2},
#  {'_id': 'Favorite Chicken', 'count': 4},
#  {'_id': 'Market Cafe', 'count': 4},
#  {'_id': 'Maries Emporium', 'count': 2},
#  {'_id': 'Munchbox Mummas', 'count': 2},
#  {'_id': 'Whitehouse Tandoori', 'count': 2},
#  {'_id': 'Halliwell Care Home', 'count': 2},
#  {'_id': 'We Remember When Lunch Club', 'count': 2},
#  {'_id': 'Double Dragon', 'count': 4},
#  {'_id': 'Sugar Loaves', 'count': 2},
#  {'_id': 'Sun in the sands', 'count': 2},
#  {'_id': 'Herne Bay Tennis Club', 'count': 2},
#  {'_id': 'Crown', 'count': 6},
#  {'_id': 'Montrose Guest House', 'count': 2},
#  {'_id': "Mimi's Kitchen", 'count': 4},
#  {'_id': 'Burger Trap', 'count': 2},
#  {'_id': "Mr Pepper's Hot Potato", 'count': 2},
#  {'_id': 'Moldova Restaurant', 'count': 2},
#  {'_id': 'Cafe Kussan', 'count': 2},
#  {'_id': 'Wells Primary School', 'count': 2},
#  {'_id': 'MV Moon clipper', 'count': 2},
#  {'_id': 'Thorley Christian Centre', 'count': 2},
#  {'_id': 'Fairways Childcare', 'count': 2},
#  {'_id': 'Newsboy', 'count': 2},
#  {'_id': 'The South Essex Golf Club', 'count': 2},
#  {'_id': 'Sussex Farm Holidays', 'count': 2},
#  {'_id': 'Noor Supermarket', 'count': 2},
#  {'_id': "Mo's Fish & Chips", 'count': 2},
#  {'_id': 'Edwards & Ward Limited At Castilion Primary School', 'count': 2},
#  {'_id': 'Coffee Master Vibe', 'count': 2},
#  {'_id': 'Moon & Stars', 'count': 2},
#  {'_id': 'Pashtriku Restaurant', 'count': 2},
#  {'_id': "Flo's Fryer", 'count': 2},
#  ...]

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
establishments_collection.find_one({})
# Out:
# {'_id': ObjectId('63d0044f873235b668973869'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %%
establishments_collection.count_documents( {"BusinessTypeID": "5" } )
# Out:
# 0

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}
results = establishments_collection.find(query)

# Use count_documents to display the number of documents in the result
establishments_collection.count_documents(query)


# Display the first document in the results using pprint
# Out:
# 82

# %%
for i in range(results.count()):
    pprint(results[i])
# Out:
# /Users/gussiepoole/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897539b'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': 'Hall Lane',
#  'AddressLine2': 'Walton-on-the-Naze',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Brenalwood',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4617.965823673803,
#  'FHRSID': 612039,
#  'LocalAuthorityBusinessID': '1970/FOOD',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CO14 8HN',
#  'RatingDate': '2022-06-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897571c'),
#  'geocode': {'latitude': 51.857536, 'longitude': 1.278721},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/612039',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '53 Marine Parade East',
#  'AddressLine2': 'Clacton On Sea',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Melrose Hotel',
#  'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  'ChangesByServerID': 0,
#  'Distance': 4619.6561440278165,
#  'FHRSID': 730933,
#  'LocalAuthorityBusinessID': '1698/FOOD',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CO15 6AD',
#  'RatingDate': '2021-08-13T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668975a26'),
#  'geocode': {'latitude': 51.789429, 'longitude': 1.15927},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/730933',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '4 High Street',
#  'AddressLine2': 'Seaford',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Seaford Pizza',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4620.421724673841,
#  'FHRSID': 172735,
#  'LocalAuthorityBusinessID': 'PI/000023858',
#  'LocalAuthorityCode': '105',
#  'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#  'LocalAuthorityName': 'Lewes',
#  'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN25 1PG',
#  'RatingDate': '2021-12-23T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668975c14'),
#  'geocode': {'latitude': 50.770885, 'longitude': 0.10202},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/172735',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '5 South Street',
#  'AddressLine2': 'Seaford',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Golden Palace',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4620.437179097401,
#  'FHRSID': 172953,
#  'LocalAuthorityBusinessID': 'PI/000024532',
#  'LocalAuthorityCode': '105',
#  'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#  'LocalAuthorityName': 'Lewes',
#  'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN25 1HP',
#  'RatingDate': '2021-10-07T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668975c23'),
#  'geocode': {'latitude': 50.770724, 'longitude': 0.101446},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/172953',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '777 Southchurch Road',
#  'AddressLine2': 'Southend-On-Sea',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': "Ashby's Butchers",
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4625.565258384611,
#  'FHRSID': 512854,
#  'LocalAuthorityBusinessID': '12/00816/BUTH',
#  'LocalAuthorityCode': '893',
#  'LocalAuthorityEmailAddress': 'EnvironmentalHealth@southend.gov.uk',
#  'LocalAuthorityName': 'Southend-On-Sea',
#  'LocalAuthorityWebSite': 'http://www.southend.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS1 2PP',
#  'RatingDate': '2022-07-21T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b6689765c2'),
#  'geocode': {'latitude': 51.541448, 'longitude': 0.736349},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/512854',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '33 Alexandra Street',
#  'AddressLine2': 'Southend-on-sea',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'South Sea Express Cuisine',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4626.200132034163,
#  'FHRSID': 1537089,
#  'LocalAuthorityBusinessID': '22/00224/RESTUN',
#  'LocalAuthorityCode': '893',
#  'LocalAuthorityEmailAddress': 'EnvironmentalHealth@southend.gov.uk',
#  'LocalAuthorityName': 'Southend-On-Sea',
#  'LocalAuthorityWebSite': 'http://www.southend.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS1 1BW',
#  'RatingDate': '2022-08-03T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b6689767e3'),
#  'geocode': {'latitude': 51.5350065, 'longitude': 0.7121671},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1537089',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '7 London Road',
#  'AddressLine2': 'Rayleigh',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Golden Palace',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4632.27689004769,
#  'FHRSID': 155648,
#  'LocalAuthorityBusinessID': 'EH/00006058',
#  'LocalAuthorityCode': '118',
#  'LocalAuthorityEmailAddress': 'customerservices@rochford.gov.uk',
#  'LocalAuthorityName': 'Rochford',
#  'LocalAuthorityWebSite': 'http://www.rochford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS6 9HN',
#  'RatingDate': '2022-03-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668977d0e'),
#  'geocode': {'latitude': 51.591515, 'longitude': 0.602364},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/155648',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '3 The Village',
#  'AddressLine2': 'Chiddingstone',
#  'AddressLine3': 'KENT',
#  'AddressLine4': '',
#  'BusinessName': 'The Tulip Tree',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4633.934040834287,
#  'FHRSID': 1012883,
#  'LocalAuthorityBusinessID': '17/00110/MIXED/S',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN8 7AH',
#  'RatingDate': '2022-03-04T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668978152'),
#  'geocode': {'latitude': 51.1859474182129, 'longitude': 0.146449998021126},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1012883',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '',
#  'AddressLine2': '81 Southernhay',
#  'AddressLine3': 'Basildon',
#  'AddressLine4': 'Essex',
#  'BusinessName': 'F & S',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4636.552523353182,
#  'FHRSID': 644109,
#  'LocalAuthorityBusinessID': '41811',
#  'LocalAuthorityCode': '109',
#  'LocalAuthorityEmailAddress': 'ehs@basildon.gov.uk',
#  'LocalAuthorityName': 'Basildon',
#  'LocalAuthorityWebSite': 'http://www.basildon.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS14 1EU',
#  'RatingDate': '2021-07-26T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668978964'),
#  'geocode': {'latitude': 51.57005, 'longitude': 0.462307},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/644109',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '17 London Road',
#  'AddressLine2': 'Riverhead',
#  'AddressLine3': 'KENT',
#  'AddressLine4': '',
#  'BusinessName': 'Longhouse',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.703065274148,
#  'FHRSID': 267034,
#  'LocalAuthorityBusinessID': '11/00102/MIXED',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN13 2BU',
#  'RatingDate': '2022-07-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b6689789d4'),
#  'geocode': {'latitude': 51.284795, 'longitude': 0.169685},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/267034',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 25}}
# {'AddressLine1': 'Downsview Community Primary School',
#  'AddressLine2': 'Beech Avenue',
#  'AddressLine3': 'Swanley',
#  'AddressLine4': 'KENT',
#  'BusinessName': 'Westview Playgroup Based At Downsview Comm Primary',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4640.152449114619,
#  'FHRSID': 972876,
#  'LocalAuthorityBusinessID': '17/00059/FOOD/S',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BR8 8AU',
#  'RatingDate': '2022-03-16T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897908a'),
#  'geocode': {'latitude': 51.3954686, 'longitude': 0.1864034},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/972876',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': 'EMR Erith',
#  'AddressLine2': 'Manor Road',
#  'AddressLine3': 'Erith',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Whatever The Weather Coffee',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4642.935252133844,
#  'FHRSID': 1417416,
#  'LocalAuthorityBusinessID': '21/00350/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA8 2AD',
#  'RatingDate': '2022-02-17T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668979958'),
#  'geocode': {'latitude': 51.4774259502039, 'longitude': 0.19265740017645},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1417416',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '43 Kings Road',
#  'AddressLine2': 'Brentwood',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Kings Restaurant (Oriental)',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.277277495872,
#  'FHRSID': 1384371,
#  'LocalAuthorityBusinessID': '21/00062/MIXED',
#  'LocalAuthorityCode': '111',
#  'LocalAuthorityEmailAddress': 'envhealth@brentwood.gov.uk',
#  'LocalAuthorityName': 'Brentwood',
#  'LocalAuthorityWebSite': 'http://www.brentwood.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM14 4DJ',
#  'RatingDate': '2022-07-05T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b668979f66'),
#  'geocode': {'latitude': 51.618135, 'longitude': 0.2983},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1384371',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 25}}
# {'AddressLine1': '24 Station Lane',
#  'AddressLine2': 'Hornchurch',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Xich Lo',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4645.006441020867,
#  'FHRSID': 907216,
#  'LocalAuthorityBusinessID': '132648',
#  'LocalAuthorityCode': '516',
#  'LocalAuthorityEmailAddress': 'environmental.health@havering.gov.uk',
#  'LocalAuthorityName': 'Havering',
#  'LocalAuthorityWebSite': 'http://www.havering.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM12 6NJ',
#  'RatingDate': '2022-07-15T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897a2c2'),
#  'geocode': {'latitude': 51.561287, 'longitude': 0.220507},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/907216',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '2 - 6 Basildon Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Abbey Wood',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Asian Supermarket Ltd: T/A Best Food Wine Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.327124710291,
#  'FHRSID': 710382,
#  'LocalAuthorityBusinessID': 'PI/000194267',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897a833'),
#  'geocode': {'latitude': 51.4848146, 'longitude': 0.1070469},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/710382',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '5 - 7 Cranley Parade',
#  'AddressLine2': 'Beaconsfield Road',
#  'AddressLine3': 'Mottingham',
#  'AddressLine4': 'London',
#  'BusinessName': 'Londis',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.4482563738065,
#  'FHRSID': 1411729,
#  'LocalAuthorityBusinessID': '21/00562/MIXED',
#  'LocalAuthorityCode': '505',
#  'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#  'LocalAuthorityName': 'Bromley',
#  'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE9 4DZ',
#  'RatingDate': '2021-11-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897a8a1'),
#  'geocode': {'latitude': 51.4273993, 'longitude': 0.0460971},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1411729',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '2 The Slade',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Costcutter',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.814121604596,
#  'FHRSID': 1060293,
#  'LocalAuthorityBusinessID': 'PI/000206588',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2NB',
#  'RatingDate': '2022-03-14T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897aafe'),
#  'geocode': {'latitude': 51.4800266, 'longitude': 0.0888789},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1060293',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '8 Porters Avenue',
#  'AddressLine3': '',
#  'AddressLine4': 'Dagenham',
#  'BusinessName': 'La Simon Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.937954737693,
#  'FHRSID': 1243155,
#  'LocalAuthorityBusinessID': '75460',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM8 2AQ',
#  'RatingDate': '2022-03-30T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897b0df'),
#  'geocode': {'latitude': 51.5515791, 'longitude': 0.1300921},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1243155',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '87 Longbridge Road',
#  'AddressLine3': '',
#  'AddressLine4': 'Barking',
#  'BusinessName': 'Caribiscus Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.2374619583225,
#  'FHRSID': 1210197,
#  'LocalAuthorityBusinessID': '75196',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG11 8TB',
#  'RatingDate': '2022-06-20T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897b68e'),
#  'geocode': {'latitude': 51.541715, 'longitude': 0.084452},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1210197',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '66 Station Parade',
#  'AddressLine3': '',
#  'AddressLine4': 'Barking',
#  'BusinessName': 'Kennedy Fried Chicken',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4649.2519200445495,
#  'FHRSID': 108663,
#  'LocalAuthorityBusinessID': '38915',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG11 8EA',
#  'RatingDate': '2022-06-11T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897b6b1'),
#  'geocode': {'latitude': 51.539293, 'longitude': 0.081616},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/108663',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '5 High Street South',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Gah Shing',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4649.903793551815,
#  'FHRSID': 1107748,
#  'LocalAuthorityBusinessID': '19/00222/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 6EN',
#  'RatingDate': '2022-05-11T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897b985'),
#  'geocode': {'latitude': 51.531385, 'longitude': 0.055764},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1107748',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '221 Ilford Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Ilford',
#  'BusinessName': 'A1 News & Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4649.968842000992,
#  'FHRSID': 570096,
#  'LocalAuthorityBusinessID': '178447',
#  'LocalAuthorityCode': '526',
#  'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#  'LocalAuthorityName': 'Redbridge',
#  'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG1 2RZ',
#  'RatingDate': '2021-06-02T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897b9c4'),
#  'geocode': {'latitude': 51.551624, 'longitude': 0.074347},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/570096',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '',
#  'AddressLine2': '108 Ilford Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Ilford',
#  'BusinessName': 'Cakes & Bakes',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.123644180097,
#  'FHRSID': 1500698,
#  'LocalAuthorityBusinessID': '201759',
#  'LocalAuthorityCode': '526',
#  'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#  'LocalAuthorityName': 'Redbridge',
#  'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG1 2LD',
#  'RatingDate': '2022-05-19T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bad0'),
#  'geocode': {'latitude': 51.5540755, 'longitude': 0.0725645},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1500698',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '149 Ley Street',
#  'AddressLine3': '',
#  'AddressLine4': 'Ilford',
#  'BusinessName': 'Sahajanand Catering Limited',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.2394323606195,
#  'FHRSID': 1318114,
#  'LocalAuthorityBusinessID': '200845',
#  'LocalAuthorityCode': '526',
#  'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#  'LocalAuthorityName': 'Redbridge',
#  'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG1 4BL',
#  'RatingDate': '2022-07-04T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bb8f'),
#  'geocode': {'latitude': 51.562276, 'longitude': 0.077645},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1318114',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '151 - 153 Barking Road',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Sisko Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.247785381525,
#  'FHRSID': 1498084,
#  'LocalAuthorityBusinessID': '22/00797/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 1LD',
#  'RatingDate': '2022-04-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bb9e'),
#  'geocode': {'latitude': 51.531936, 'longitude': 0.046878},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1498084',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '221 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Magazin Romanesc Diana',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4650.389970646722,
#  'FHRSID': 1063454,
#  'LocalAuthorityBusinessID': '18/00285/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 1JG',
#  'RatingDate': '2022-07-25T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bc8b'),
#  'geocode': {'latitude': 51.53963, 'longitude': 0.050713},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1063454',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '241B High Street North',
#  'AddressLine2': 'Manor Park',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Bali Maamalas',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.459698178172,
#  'FHRSID': 1130121,
#  'LocalAuthorityBusinessID': '19/00249/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E12 6SJ',
#  'RatingDate': '2022-05-11T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bd03'),
#  'geocode': {'latitude': 51.541156, 'longitude': 0.050334},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1130121',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '333 Barking Road',
#  'AddressLine2': 'Plaistow',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Angels Bakery',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.822100156243,
#  'FHRSID': 640363,
#  'LocalAuthorityBusinessID': '10/00269/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8EE',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bf4c'),
#  'geocode': {'latitude': 51.52189, 'longitude': 0.021028},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640363',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '282 Barking Road',
#  'AddressLine2': 'Plaistow',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Nikkis Place Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.85622582084,
#  'FHRSID': 640816,
#  'LocalAuthorityBusinessID': '61130/0282/0/000',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8HR',
#  'RatingDate': '2022-06-30T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897bf97'),
#  'geocode': {'latitude': 51.520147, 'longitude': 0.018342},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640816',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '369 Katherine Road',
#  'AddressLine2': 'Forest Gate',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Chicago 30',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.9448351911105,
#  'FHRSID': 1530599,
#  'LocalAuthorityBusinessID': '22/01037/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E7 8LT',
#  'RatingDate': '2022-07-05T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c007'),
#  'geocode': {'latitude': 51.541658, 'longitude': 0.037523},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1530599',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': 'The Kinema',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Dunmow',
#  'AddressLine4': '',
#  'BusinessName': 'Samui Thai Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4651.0999945416315,
#  'FHRSID': 668674,
#  'LocalAuthorityBusinessID': '14/00082/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1HB',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c116'),
#  'geocode': {'latitude': 51.8686712, 'longitude': 0.3659018},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/668674',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '76 Green Street',
#  'AddressLine2': 'Forest Gate',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Pakhtoonkhwa Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4651.2331297369665,
#  'FHRSID': 1286585,
#  'LocalAuthorityBusinessID': '20/00532/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E7 8JG',
#  'RatingDate': '2022-06-14T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c201'),
#  'geocode': {'latitude': 51.543994, 'longitude': 0.031959},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1286585',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '23 Stortford Road',
#  'AddressLine2': 'Dunmow',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'New Happy Garden',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4651.44448783849,
#  'FHRSID': 971735,
#  'LocalAuthorityBusinessID': '17/00076/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1DA',
#  'RatingDate': '2022-03-28T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c2b3'),
#  'geocode': {'latitude': 51.873055, 'longitude': 0.360846},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/971735',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '34 West Ham Lane',
#  'AddressLine2': 'Stratford',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Mummy Yum',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4652.049759667773,
#  'FHRSID': 1055935,
#  'LocalAuthorityBusinessID': '18/00198/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E15 4SA',
#  'RatingDate': '2022-07-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c45a'),
#  'geocode': {'latitude': 51.538857, 'longitude': 0.004389},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1055935',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '345 High Road Leytonstone',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'Gospodina',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4652.63219028813,
#  'FHRSID': 1177878,
#  'LocalAuthorityBusinessID': '347294',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 4JT',
#  'RatingDate': '2022-06-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c5e5'),
#  'geocode': {'latitude': 51.555782, 'longitude': 0.005407},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1177878',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '32 Church Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': "Leo's Bar & Grill",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4652.953922367066,
#  'FHRSID': 1296829,
#  'LocalAuthorityBusinessID': '347449',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'E11 1HG',
#  'RatingDate': '2022-06-15T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897c6d3'),
#  'geocode': {'latitude': 51.568245, 'longitude': 0.009101},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1296829',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '',
#  'AddressLine2': '14 Hatch Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Chingford',
#  'BusinessName': 'Royal Ribs',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4654.920995700347,
#  'FHRSID': 514573,
#  'LocalAuthorityBusinessID': '44243',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E4 6LQ',
#  'RatingDate': '2022-07-01T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d0044f873235b66897ca47'),
#  'geocode': {'latitude': 51.61912, 'longitude': 0.006248},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/514573',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': 'Great Hallingbury Manor',
# ...
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8EE',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d38b4c'),
#  'geocode': {'latitude': 51.52189, 'longitude': 0.021028},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640363',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '282 Barking Road',
#  'AddressLine2': 'Plaistow',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Nikkis Place Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.85622582084,
#  'FHRSID': 640816,
#  'LocalAuthorityBusinessID': '61130/0282/0/000',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8HR',
#  'RatingDate': '2022-06-30T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d38b97'),
#  'geocode': {'latitude': 51.520147, 'longitude': 0.018342},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640816',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '369 Katherine Road',
#  'AddressLine2': 'Forest Gate',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Chicago 30',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.9448351911105,
#  'FHRSID': 1530599,
#  'LocalAuthorityBusinessID': '22/01037/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E7 8LT',
#  'RatingDate': '2022-07-05T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d38c07'),
#  'geocode': {'latitude': 51.541658, 'longitude': 0.037523},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1530599',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': 'The Kinema',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Dunmow',
#  'AddressLine4': '',
#  'BusinessName': 'Samui Thai Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4651.0999945416315,
#  'FHRSID': 668674,
#  'LocalAuthorityBusinessID': '14/00082/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1HB',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d38d16'),
#  'geocode': {'latitude': 51.8686712, 'longitude': 0.3659018},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/668674',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '76 Green Street',
#  'AddressLine2': 'Forest Gate',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Pakhtoonkhwa Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4651.2331297369665,
#  'FHRSID': 1286585,
#  'LocalAuthorityBusinessID': '20/00532/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E7 8JG',
#  'RatingDate': '2022-06-14T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d38e01'),
#  'geocode': {'latitude': 51.543994, 'longitude': 0.031959},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1286585',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '23 Stortford Road',
#  'AddressLine2': 'Dunmow',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'New Happy Garden',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4651.44448783849,
#  'FHRSID': 971735,
#  'LocalAuthorityBusinessID': '17/00076/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1DA',
#  'RatingDate': '2022-03-28T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d38eb3'),
#  'geocode': {'latitude': 51.873055, 'longitude': 0.360846},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/971735',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '34 West Ham Lane',
#  'AddressLine2': 'Stratford',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Mummy Yum',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4652.049759667773,
#  'FHRSID': 1055935,
#  'LocalAuthorityBusinessID': '18/00198/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E15 4SA',
#  'RatingDate': '2022-07-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d3905a'),
#  'geocode': {'latitude': 51.538857, 'longitude': 0.004389},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1055935',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '345 High Road Leytonstone',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'Gospodina',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4652.63219028813,
#  'FHRSID': 1177878,
#  'LocalAuthorityBusinessID': '347294',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 4JT',
#  'RatingDate': '2022-06-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d391e5'),
#  'geocode': {'latitude': 51.555782, 'longitude': 0.005407},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1177878',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '32 Church Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': "Leo's Bar & Grill",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4652.953922367066,
#  'FHRSID': 1296829,
#  'LocalAuthorityBusinessID': '347449',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'E11 1HG',
#  'RatingDate': '2022-06-15T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d392d3'),
#  'geocode': {'latitude': 51.568245, 'longitude': 0.009101},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1296829',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '',
#  'AddressLine2': '14 Hatch Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Chingford',
#  'BusinessName': 'Royal Ribs',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4654.920995700347,
#  'FHRSID': 514573,
#  'LocalAuthorityBusinessID': '44243',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E4 6LQ',
#  'RatingDate': '2022-07-01T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d39647'),
#  'geocode': {'latitude': 51.61912, 'longitude': 0.006248},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/514573',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': 'Great Hallingbury Manor',
#  'AddressLine2': 'Tilekiln Green',
#  'AddressLine3': 'Great Hallingbury',
#  'AddressLine4': 'Bishops Stortford',
#  'BusinessName': 'Great Hallingbury Manor Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4656.798774391753,
#  'FHRSID': 124507,
#  'LocalAuthorityBusinessID': '53022999151',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM22 7TJ',
#  'RatingDate': '2021-07-28T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': '1',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d39840'),
#  'geocode': {'latitude': 51.8686828613281, 'longitude': 0.207771003246307},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/124507',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '58 Lower Street',
#  'AddressLine2': 'Stansted',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'The Dog And Duck',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4658.344880326824,
#  'FHRSID': 479001,
#  'LocalAuthorityBusinessID': '12/00162/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM24 8LR',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d39a60'),
#  'geocode': {'latitude': 51.904039, 'longitude': 0.201087},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/479001',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '1 Mercers Row',
#  'AddressLine2': 'Saffron Walden',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Oriental Cottage',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4661.334349371914,
#  'FHRSID': 107710,
#  'LocalAuthorityBusinessID': '38127001007',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CB10 1HD',
#  'RatingDate': '2022-03-31T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d00500a578528220d39c4e'),
#  'geocode': {'latitude': 52.02328, 'longitude': 0.240491},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/107710',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}

# %% [raw]
# # Convert the result to a Pandas DataFrame
#
# # Display the number of rows in the DataFrame
#
# # Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query =

# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint
# Out:
#   File "/var/folders/f1/wjgj_bsj33ld2npn84ytlxz00000gn/T/ipykernel_98149/2513243106.py", line 2
#     query =
#            ^
# SyntaxError: invalid syntax

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
